# %%
import pandas as pd

# read csv file
stat = pd.read_csv ("stat.csv")

# %%
stat.tail
# Out:
# <bound method NDFrame.tail of       ID Q1: 您的生理性別 Gender  Q2: 你的出生西元年 your birth year  \
# 0      1                 男                         1993
# 1      2                 女                         1995
# 2      3                 女                         1995
# 3      4                 女                         1996
# 4      5                 女                         1998
# ..   ...               ...                          ...
# 895  896                 女                         2003
# 896  897                 女                         2004
# 897  898                 男                         2004
# 898  899                 男                         2004
# 899  900                 男                         2004
#
#         Q3: 您的星座 constellation      \
# 0       1. 水瓶座(1/20-2/18) Aquarius
# 1       1. 水瓶座(1/20-2/18) Aquarius
# 2       1. 水瓶座(1/20-2/18) Aquarius
# 3       1. 水瓶座(1/20-2/18) Aquarius
# 4       1. 水瓶座(1/20-2/18) Aquarius
# ..                             ...
# ...

# %%
source = list(stat['您的性格傾向'])
print(ls[0:3])
